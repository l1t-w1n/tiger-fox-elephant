# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.append(str(project_root))

from config.config import Config
from utils.helper_functions import create_X_y
from utils.visualization import plot_examples
from utils.visualization import plot_model_performance, visualize_misclassified,plot_all_examples
from models.baseline.baseline_cnn import AnimalDataset
from utils.helper_fns_for_optuna import load_optimized_model, evaluate_optimized_model

# %%
tiger_model, tiger_history = load_optimized_model("tiger_optuna_final")

tiger = ['Tiger_negative _class_for_test', 'tiger_for_test']
X_test, y_test = create_X_y(tiger)
#print(y_test),

#plot_all_examples(X_test, y_test)

test_dataset = AnimalDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Plot performance metrics
plot_model_performance(tiger_model, test_loader, "tiger", Config.device, evaluate_optimized_model)
visualize_misclassified(tiger_model, test_loader, "tiger", Config.device, optimized=True)
# Out:
# Model Predictions Shape: (50,)
# True Labels Shape: (50,)
#
# Detailed Metrics:
# True Negatives: 27 (54.0%)
# False Positives: 2 (4.0%)
# False Negatives: 5 (10.0%)
# True Positives: 16 (32.0%)
# Error Analysis Summary:
# Total misclassified images shown: 7
# False Positives (incorrectly predicted as tiger): 2
# False Negatives (incorrectly predicted as not tiger): 5

# %%
fox_model, fox_history = load_optimized_model("fox_optuna_final")

fox = ['Fox_negative_class_for_test', 'fox_for_test']
X_test, y_test = create_X_y(fox)
#print(y_test),

#plot_all_examples(X_test, y_test)

test_dataset = AnimalDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Plot performance metrics
plot_model_performance(fox_model, test_loader, "fox", Config.device, evaluate_optimized_model)
visualize_misclassified(fox_model, test_loader, "fox", Config.device, optimized=True)
# Out:
# Model Predictions Shape: (17,)
# True Labels Shape: (17,)
#
# Detailed Metrics:
# True Negatives: 9 (52.9%)
# False Positives: 0 (0.0%)
# False Negatives: 0 (0.0%)
# True Positives: 8 (47.1%)
# No misclassified images found!

# %%
elephant_model, elephant_history = load_optimized_model("elephant_optuna_final")

elephant = ['Elephant_negative_class_for_test', 'elephant_for_test']
X_test, y_test = create_X_y(elephant)
#print(y_test),

#plot_all_examples(X_test, y_test)

test_dataset = AnimalDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Plot performance metrics
plot_model_performance(elephant_model, test_loader, "elephant", Config.device, evaluate_optimized_model)
visualize_misclassified(elephant_model, test_loader, "elephant", Config.device, optimized=True)
# Out:
# Model Predictions Shape: (22,)
# True Labels Shape: (22,)
#
# Detailed Metrics:
# True Negatives: 6 (27.3%)
# False Positives: 4 (18.2%)
# False Negatives: 1 (4.5%)
# True Positives: 11 (50.0%)
# Error Analysis Summary:
# Total misclassified images shown: 5
# False Positives (incorrectly predicted as elephant): 4
# False Negatives (incorrectly predicted as not elephant): 1
